# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score 
import matplotlib.pyplot as plt
import re

# CSV 파일에서 데이터 로드
file_path = '20240703_correlation.csv'
df = pd.read_csv(file_path)

# 열 목록
columns = df.columns

# R^2 값을 저장할 행렬 초기화
r2_matrix = pd.DataFrame(index=columns, columns=columns)

# 각 열을 종속 변수로 지정
for dependent_var in columns:
    independent_vars = df.columns.difference([dependent_var])
    
    for var in independent_vars:
        # 결측치 제거
        valid_data = df[[var, dependent_var]].dropna()
        
        X = valid_data[[var]]
        y = valid_data[dependent_var]
        
        if len(valid_data) > 0:  # 유효한 데이터가 있는지 확인
            # 다항식 특징 변환기 생성 (차수 3으로 설정)
            poly = PolynomialFeatures(degree=3)
            X_poly = poly.fit_transform(X)
            
            # 모델 훈련
            model = LinearRegression()
            model.fit(X_poly, y)
            
            # 예측
            y_pred = model.predict(X_poly)
            
            # R^2 계산
            r2 = r2_score(y, y_pred)
            r2_matrix.loc[var, dependent_var] = r2

            # 계수 출력
            intercept, coef_linear, coef_quadratic, coef_cubic = model.intercept_, model.coef_[1], model.coef_[2], model.coef_[3]
            print(f'Independent Var: {var}, Dependent Var: {dependent_var}')
            print(f'Intercept: {intercept}, Linear Coeff: {coef_linear}, Quadratic Coeff: {coef_quadratic}, Cubic Coeff: {coef_cubic}')
        else:
            r2_matrix.loc[var, dependent_var] = np.nan  # 유효한 데이터가 없으면 NaN으로 설정

# r2_matrix를 CSV 파일로 저장
output_file_path = '20240710_cubic_r2.csv'  # 저장할 파일 경로
r2_matrix.to_csv(output_file_path)

# R^2 값이 0.9 이상인 모델 찾기
high_r2_models = r2_matrix[r2_matrix >= 0.90].stack().reset_index()
high_r2_models.columns = ['Independent_Var', 'Dependent_Var', 'R2']
# Out:
# Independent Var: 0-0_S1 (eV), Dependent Var: homo (eV)
# Intercept: -2.6167777245981956, Linear Coeff: -5.461586336389485, Quadratic Coeff: 2.5861617475828362, Cubic Coeff: -0.5063950148890051
# Independent Var: 0-0_T1 (eV), Dependent Var: homo (eV)
# Intercept: -5.084569190808076, Linear Coeff: -1.5001091457452886, Quadratic Coeff: -0.2583936438704736, Cubic Coeff: 0.1449067070381196
# Independent Var: adiabatic_S1-S0 (kcal/mol), Dependent Var: homo (eV)
# Intercept: -2.5312986131526563, Linear Coeff: -0.2315374202111497, Quadratic Coeff: 0.004541296740252133, Cubic Coeff: -3.763678664622794e-05
# Independent Var: adiabatic_T1-S0 (kcal/mol), Dependent Var: homo (eV)
# Intercept: -5.109391145137565, Linear Coeff: -0.06403011884066917, Quadratic Coeff: -0.0005433201657650739, Cubic Coeff: 1.2589824246109216e-05
# Independent Var: dipole_moment_norm_S0 (D), Dependent Var: homo (eV)
# Intercept: -7.104650552852073, Linear Coeff: -0.059496185623663954, Quadratic Coeff: 0.010383427963328657, Cubic Coeff: -0.00020783337779361338
# Independent Var: dipole_moment_norm_S1 (D), Dependent Var: homo (eV)
# Intercept: -7.178022897165497, Linear Coeff: -0.04277122901194922, Quadratic Coeff: 0.009042459325786508, Cubic Coeff: -0.00017647045639327535
# Independent Var: dipole_moment_norm_T1 (D), Dependent Var: homo (eV)
# Intercept: -7.606152278759414, Linear Coeff: 0.019501859390283195, Quadratic Coeff: 0.0030037636296299736, Cubic Coeff: -6.537634670614884e-05
# Independent Var: lumo (eV), Dependent Var: homo (eV)
# Intercept: 41.918084088638636, Linear Coeff: 35.00593098004835, Quadratic Coeff: 8.644492555059514, Cubic Coeff: 0.7396743821646012
# Independent Var: lumo-homo (eV), Dependent Var: homo (eV)
# Intercept: -3.474156314628823, Linear Coeff: -1.0750773199282355, Quadratic Coeff: -0.04731695578006859, Cubic Coeff: 0.008654116425665714
# Independent Var: oxidation_S0 (kcal/mol), Dependent Var: homo (eV)
# Intercept: -3.7375828666108024, Linear Coeff: -4.977275287022629e-07, Quadratic Coeff: -0.00014685370571020017, Cubic Coeff: 1.4399628871164648e-10
# Independent Var: reduction_S0 (kcal/mol), Dependent Var: homo (eV)
# Intercept: 43.58037944509965, Linear Coeff: 1.3371770097674873, Quadratic Coeff: 0.012243377947770818, Cubic Coeff: 3.914620673128866e-05
# Independent Var: vertical_excitation_energy (eV), Dependent Var: homo (eV)
# Intercept: -2.6453418661765022, Linear Coeff: -3.682868703536005, Quadratic Coeff: 1.3110150350418466, Cubic Coeff: -0.23666523197191536
# Independent Var: 0-0_S1 (eV), Dependent Var: lumo (eV)
# Intercept: -2.8661519877362087, Linear Coeff: -1.8191895972490888, Quadratic Coeff: 1.0747620533982336, Cubic Coeff: -0.21210375502604184
# Independent Var: 0-0_T1 (eV), Dependent Var: lumo (eV)
# Intercept: -3.5262048682106553, Linear Coeff: -0.5604773791132301, Quadratic Coeff: 0.24809847553451617, Cubic Coeff: -0.0373899327072289
# Independent Var: adiabatic_S1-S0 (kcal/mol), Dependent Var: lumo (eV)
# Intercept: -2.669456369719521, Linear Coeff: -0.08919328046759817, Quadratic Coeff: 0.002191005331501972, Cubic Coeff: -1.8063491256894992e-05
# Independent Var: adiabatic_T1-S0 (kcal/mol), Dependent Var: lumo (eV)
# Intercept: -3.5304618913599, Linear Coeff: -0.02437732129418628, Quadratic Coeff: 0.0004808481039237906, Cubic Coeff: -3.329145230608621e-06
# Independent Var: dipole_moment_norm_S0 (D), Dependent Var: lumo (eV)
# Intercept: -3.93725911787919, Linear Coeff: 0.009070549816248174, Quadratic Coeff: -0.0007086934700379504, Cubic Coeff: 3.615424571071224e-05
# Independent Var: dipole_moment_norm_S1 (D), Dependent Var: lumo (eV)
# Intercept: -3.9400040325753647, Linear Coeff: 0.014343424641080413, Quadratic Coeff: -0.0014563225137444384, Cubic Coeff: 6.076411666411721e-05
# Independent Var: dipole_moment_norm_T1 (D), Dependent Var: lumo (eV)
# Intercept: -4.043829823673936, Linear Coeff: 0.025800096598593905, Quadratic Coeff: -0.0011387652056612568, Cubic Coeff: 1.606199946980677e-05
# Independent Var: homo (eV), Dependent Var: lumo (eV)
# Intercept: 10.55217693477632, Linear Coeff: 5.997271693977073, Quadratic Coeff: 0.8557275485967937, Cubic Coeff: 0.0419406985866253
# Independent Var: lumo-homo (eV), Dependent Var: lumo (eV)
# Intercept: -3.4741563146288073, Linear Coeff: -0.07507731992825414, Quadratic Coeff: -0.04731695578006283, Cubic Coeff: 0.008654116425665118
# Independent Var: oxidation_S0 (kcal/mol), Dependent Var: lumo (eV)
# Intercept: -3.120140201748973, Linear Coeff: -1.1801461199094654e-07, Quadratic Coeff: -3.4820021195149e-05, Cubic Coeff: 3.414250809144065e-11
# Independent Var: reduction_S0 (kcal/mol), Dependent Var: lumo (eV)
# Intercept: -10.420327339247269, Linear Coeff: -0.29025758027566967, Quadratic Coeff: -0.00336537224757501, Cubic Coeff: -1.1260631805454224e-05
# Independent Var: vertical_excitation_energy (eV), Dependent Var: lumo (eV)
# Intercept: -3.3367266379619114, Linear Coeff: -0.4533381548095075, Quadratic Coeff: 0.11372371231807399, Cubic Coeff: -0.010758646817460082
# Independent Var: 0-0_S1 (eV), Dependent Var: vertical_excitation_energy (eV)
# Intercept: 0.6503660595178078, Linear Coeff: 0.4490434957296852, Quadratic Coeff: 0.48662067628355365, Cubic Coeff: -0.1280422915187313
# Independent Var: 0-0_T1 (eV), Dependent Var: vertical_excitation_energy (eV)
# Intercept: 0.8233359519051509, Linear Coeff: 1.2768371869394914, Quadratic Coeff: 0.0797052806101633, Cubic Coeff: -0.1167630471052079
# Independent Var: adiabatic_S1-S0 (kcal/mol), Dependent Var: vertical_excitation_energy (eV)
# Intercept: 0.6264032827612924, Linear Coeff: 0.01682346240663717, Quadratic Coeff: 0.001033710691436708, Cubic Coeff: -1.1571988774793096e-05
# Independent Var: adiabatic_T1-S0 (kcal/mol), Dependent Var: vertical_excitation_energy (eV)
# Intercept: 0.8570009631652997, Linear Coeff: 0.05283646050238453, Quadratic Coeff: 0.0002538336503645673, Cubic Coeff: -1.0859492697301576e-05
# Independent Var: dipole_moment_norm_S0 (D), Dependent Var: vertical_excitation_energy (eV)
# Intercept: 2.242871304223913, Linear Coeff: 0.04921344040877999, Quadratic Coeff: -0.006957236825627673, Cubic Coeff: 0.00012221261127972477
# Independent Var: dipole_moment_norm_S1 (D), Dependent Var: vertical_excitation_energy (eV)
# Intercept: 2.295896541970412, Linear Coeff: 0.044050821280372486, Quadratic Coeff: -0.006938708727958953, Cubic Coeff: 0.0001281217251763167
# Independent Var: dipole_moment_norm_T1 (D), Dependent Var: vertical_excitation_energy (eV)
# Intercept: 2.3987872331769853, Linear Coeff: 0.03240115456813903, Quadratic Coeff: -0.004175939793443493, Cubic Coeff: 7.268095323331031e-05
# Independent Var: homo (eV), Dependent Var: vertical_excitation_energy (eV)
# Intercept: 9.03725214431662, Linear Coeff: 4.87240014411535, Quadratic Coeff: 0.897964094303604, Cubic Coeff: 0.048527946976472336
# Independent Var: lumo (eV), Dependent Var: vertical_excitation_energy (eV)
# Intercept: -28.136191050545413, Linear Coeff: -23.11615266653701, Quadratic Coeff: -5.910166280685815, Cubic Coeff: -0.5073697026635813
# Independent Var: lumo-homo (eV), Dependent Var: vertical_excitation_energy (eV)
# Intercept: 0.11480981062092432, Linear Coeff: 0.0214547617800964, Quadratic Coeff: 0.431259702645067, Cubic Coeff: -0.06825984716502308
# Independent Var: oxidation_S0 (kcal/mol), Dependent Var: vertical_excitation_energy (eV)
# Intercept: 0.5460096480308598, Linear Coeff: 2.5666874960157217e-07, Quadratic Coeff: 7.573556223331171e-05, Cubic Coeff: -7.42619317193791e-11
# Independent Var: reduction_S0 (kcal/mol), Dependent Var: vertical_excitation_energy (eV)
# Intercept: -40.382267399605894, Linear Coeff: -1.2240439209345575, Quadratic Coeff: -0.011789596048862573, Cubic Coeff: -3.808005317718077e-05
# Independent Var: 0-0_S1 (eV), Dependent Var: dipole_moment_norm_S0 (D)
# Intercept: 20.864013306349495, Linear Coeff: -15.340274117087882, Quadratic Coeff: 5.075633501759472, Cubic Coeff: -0.5323522503261469
# Independent Var: 0-0_T1 (eV), Dependent Var: dipole_moment_norm_S0 (D)
# Intercept: 18.32781940960259, Linear Coeff: -21.615587176522485, Quadratic Coeff: 13.140469186980479, Cubic Coeff: -2.677154882360684
# Independent Var: adiabatic_S1-S0 (kcal/mol), Dependent Var: dipole_moment_norm_S0 (D)
# Intercept: 28.091573203580502, Linear Coeff: -1.1750985133247454, Quadratic Coeff: 0.021377155482233106, Cubic Coeff: -0.00013215917354680862
# Independent Var: adiabatic_T1-S0 (kcal/mol), Dependent Var: dipole_moment_norm_S0 (D)
# Intercept: 18.19574778795509, Linear Coeff: -0.9374340799771286, Quadratic Coeff: 0.025012080063738153, Cubic Coeff: -0.00022390996371468574
# Independent Var: dipole_moment_norm_S1 (D), Dependent Var: dipole_moment_norm_S0 (D)
# Intercept: 0.4624042857139621, Linear Coeff: 0.8670565371208863, Quadratic Coeff: 0.012625665246748997, Cubic Coeff: -0.0005220700640302667
# Independent Var: dipole_moment_norm_T1 (D), Dependent Var: dipole_moment_norm_S0 (D)
# Intercept: 4.907153741593696, Linear Coeff: -0.1158952448497953, Quadratic Coeff: 0.020604010040932985, Cubic Coeff: -0.00016434971570980506
# Independent Var: homo (eV), Dependent Var: dipole_moment_norm_S0 (D)
# Intercept: 218.36507071464155, Linear Coeff: 80.9040538059359, Quadratic Coeff: 10.330143646654388, Cubic Coeff: 0.4417458639897802
# Independent Var: lumo (eV), Dependent Var: dipole_moment_norm_S0 (D)
# Intercept: 488.42032836983475, Linear Coeff: 371.8980440238401, Quadratic Coeff: 95.66430025167723, Cubic Coeff: 8.189384214440565
# Independent Var: lumo-homo (eV), Dependent Var: dipole_moment_norm_S0 (D)
# Intercept: 68.08689644765094, Linear Coeff: -51.34287589561114, Quadratic Coeff: 14.32118788004807, Cubic Coeff: -1.3414880379693628
# Independent Var: oxidation_S0 (kcal/mol), Dependent Var: dipole_moment_norm_S0 (D)
# Intercept: 13.006104523852853, Linear Coeff: -8.806366778072481e-07, Quadratic Coeff: -0.0002598304334451936, Cubic Coeff: 2.547747638938829e-10
# Independent Var: reduction_S0 (kcal/mol), Dependent Var: dipole_moment_norm_S0 (D)
# Intercept: 532.7076501110081, Linear Coeff: 15.190147057321655, Quadratic Coeff: 0.14636112084026248, Cubic Coeff: 0.000470070614447593
# Independent Var: vertical_excitation_energy (eV), Dependent Var: dipole_moment_norm_S0 (D)
# Intercept: 39.02430950036684, Linear Coeff: -34.483729087077265, Quadratic Coeff: 12.263786586552467, Cubic Coeff: -1.4766198249689033
# Independent Var: 0-0_S1 (eV), Dependent Var: dipole_moment_norm_S1 (D)
# Intercept: 24.644839541316884, Linear Coeff: -22.131375639757366, Quadratic Coeff: 9.015785699745068, Cubic Coeff: -1.27361546342728
# Independent Var: 0-0_T1 (eV), Dependent Var: dipole_moment_norm_S1 (D)
# Intercept: 21.296001342330644, Linear Coeff: -28.35780456669018, Quadratic Coeff: 17.90843778391253, Cubic Coeff: -3.7534968955062773
# Independent Var: adiabatic_S1-S0 (kcal/mol), Dependent Var: dipole_moment_norm_S1 (D)
# Intercept: 32.81474191759736, Linear Coeff: -1.5322639063344914, Quadratic Coeff: 0.030217700778318115, Cubic Coeff: -0.00020355183664411136
# Independent Var: adiabatic_T1-S0 (kcal/mol), Dependent Var: dipole_moment_norm_S1 (D)
# Intercept: 21.12088812618323, Linear Coeff: -1.2261071622820896, Quadratic Coeff: 0.03389735273083693, Cubic Coeff: -0.0003113491788884204
# Independent Var: dipole_moment_norm_S0 (D), Dependent Var: dipole_moment_norm_S1 (D)
# Intercept: 0.2783498327572387, Linear Coeff: 0.9614981353831068, Quadratic Coeff: -2.9007545409999447e-05, Cubic Coeff: 5.447821730231173e-05
# Independent Var: dipole_moment_norm_T1 (D), Dependent Var: dipole_moment_norm_S1 (D)
# Intercept: 4.3718080254847616, Linear Coeff: 0.011260557213409622, Quadratic Coeff: 0.014198762808929472, Cubic Coeff: -7.168360678300525e-05
# Independent Var: homo (eV), Dependent Var: dipole_moment_norm_S1 (D)
# Intercept: 259.8905814827237, Linear Coeff: 98.07955732020504, Quadratic Coeff: 12.687021582515712, Cubic Coeff: 0.5491311613282619
# Independent Var: lumo (eV), Dependent Var: dipole_moment_norm_S1 (D)
# Intercept: 452.51797834199954, Linear Coeff: 345.6084739712992, Quadratic Coeff: 89.23638116651321, Cubic Coeff: 7.6648994905127665
# Independent Var: lumo-homo (eV), Dependent Var: dipole_moment_norm_S1 (D)
# Intercept: 83.25533608361788, Linear Coeff: -65.1483212000957, Quadratic Coeff: 18.44466241386732, Cubic Coeff: -1.746990433874231
# Independent Var: oxidation_S0 (kcal/mol), Dependent Var: dipole_moment_norm_S1 (D)
# Intercept: 13.213119750760628, Linear Coeff: -9.067286133979353e-07, Quadratic Coeff: -0.0002688774384012444, Cubic Coeff: 2.6364573594888177e-10
# Independent Var: reduction_S0 (kcal/mol), Dependent Var: dipole_moment_norm_S1 (D)
# Intercept: 495.98992067271575, Linear Coeff: 14.152875546393295, Quadratic Coeff: 0.1365366206058236, Cubic Coeff: 0.0004388970431179473
# Independent Var: vertical_excitation_energy (eV), Dependent Var: dipole_moment_norm_S1 (D)
# Intercept: 49.75201443176577, Linear Coeff: -47.44142532524761, Quadratic Coeff: 17.401271638919752, Cubic Coeff: -2.1502521468829556
# Independent Var: 0-0_S1 (eV), Dependent Var: dipole_moment_norm_T1 (D)
# Intercept: 40.27050963658151, Linear Coeff: -25.957111263158332, Quadratic Coeff: 6.97377644522514, Cubic Coeff: -0.7263704491807275
# Independent Var: 0-0_T1 (eV), Dependent Var: dipole_moment_norm_T1 (D)
# Intercept: 31.510292098587094, Linear Coeff: -28.808791588144583, Quadratic Coeff: 14.049349356022097, Cubic Coeff: -2.7104682135543072
# Independent Var: adiabatic_S1-S0 (kcal/mol), Dependent Var: dipole_moment_norm_T1 (D)
# Intercept: 50.22572953721931, Linear Coeff: -1.839118693424643, Quadratic Coeff: 0.0303468913834622, Cubic Coeff: -0.00019576159016843064
# Independent Var: adiabatic_T1-S0 (kcal/mol), Dependent Var: dipole_moment_norm_T1 (D)
# Intercept: 31.6017089365288, Linear Coeff: -1.2814929875826855, Quadratic Coeff: 0.027771092488692597, Cubic Coeff: -0.00023778361193471653
# Independent Var: dipole_moment_norm_S0 (D), Dependent Var: dipole_moment_norm_T1 (D)
# Intercept: 7.423086005451709, Linear Coeff: -0.05398677550208916, Quadratic Coeff: 0.12327350191508685, Cubic Coeff: -0.0029347165395473065
# Independent Var: dipole_moment_norm_S1 (D), Dependent Var: dipole_moment_norm_T1 (D)
# Intercept: 6.660271163546537, Linear Coeff: 0.15346649127510648, Quadratic Coeff: 0.1049189073511777, Cubic Coeff: -0.0027056005588145804
# Independent Var: homo (eV), Dependent Var: dipole_moment_norm_T1 (D)
# Intercept: 22.56106567276951, Linear Coeff: -14.112157052339505, Quadratic Coeff: -3.7830436530085585, Cubic Coeff: -0.2232853651864577
# Independent Var: lumo (eV), Dependent Var: dipole_moment_norm_T1 (D)
# Intercept: 1075.7538318793584, Linear Coeff: 835.1485163533235, Quadratic Coeff: 218.41312432763092, Cubic Coeff: 19.00334153516951
# Independent Var: lumo-homo (eV), Dependent Var: dipole_moment_norm_T1 (D)
# Intercept: 55.098784861942875, Linear Coeff: -18.823528342803673, Quadratic Coeff: 1.2793250683653126, Cubic Coeff: 0.10833779627471074
# Independent Var: oxidation_S0 (kcal/mol), Dependent Var: dipole_moment_norm_T1 (D)
# Intercept: 31.80977972066399, Linear Coeff: -2.880133080002177e-06, Quadratic Coeff: -0.0008482780561056305, Cubic Coeff: 8.317726163173824e-10
# Independent Var: reduction_S0 (kcal/mol), Dependent Var: dipole_moment_norm_T1 (D)
# Intercept: 998.3905515038217, Linear Coeff: 29.266678228802835, Quadratic Coeff: 0.28995434637195466, Cubic Coeff: 0.0009578737085611522
# Independent Var: vertical_excitation_energy (eV), Dependent Var: dipole_moment_norm_T1 (D)
# Intercept: 50.193413529543335, Linear Coeff: -28.515946316419527, Quadratic Coeff: 6.840833232761004, Cubic Coeff: -0.7195333235204018
# Independent Var: 0-0_T1 (eV), Dependent Var: 0-0_S1 (eV)
# Intercept: 0.4249363549334859, Linear Coeff: 1.3228379111589077, Quadratic Coeff: -0.008817173553620772, Cubic Coeff: -0.09517208089558182
# Independent Var: adiabatic_S1-S0 (kcal/mol), Dependent Var: 0-0_S1 (eV)
# Intercept: 0.037111730300928736, Linear Coeff: 0.03872169787902242, Quadratic Coeff: 0.00011996952823230744, Cubic Coeff: -9.133553288687146e-07
# Independent Var: adiabatic_T1-S0 (kcal/mol), Dependent Var: 0-0_S1 (eV)
# Intercept: 0.4136663927174731, Linear Coeff: 0.05965082828685454, Quadratic Coeff: -7.461469572076808e-05, Cubic Coeff: -7.424588904583751e-06
# Independent Var: dipole_moment_norm_S0 (D), Dependent Var: 0-0_S1 (eV)
# Intercept: 1.8366193916625624, Linear Coeff: 0.04474454372348117, Quadratic Coeff: -0.006546849658237047, Cubic Coeff: 0.00012258607497681734
# Independent Var: dipole_moment_norm_S1 (D), Dependent Var: 0-0_S1 (eV)
# Intercept: 1.8676143010010602, Linear Coeff: 0.03233525449954588, Quadratic Coeff: -0.005224410499242659, Cubic Coeff: 8.227470375201523e-05
# Independent Var: dipole_moment_norm_T1 (D), Dependent Var: 0-0_S1 (eV)
# Intercept: 1.8479789497231374, Linear Coeff: 0.062441566090160036, Quadratic Coeff: -0.0063198413218263074, Cubic Coeff: 0.00011962389706498405
# Independent Var: homo (eV), Dependent Var: 0-0_S1 (eV)
# Intercept: 1.2029508909721884, Linear Coeff: 1.4042096520758145, Quadratic Coeff: 0.3707391745022514, Cubic Coeff: 0.022449609284187932
# Independent Var: lumo (eV), Dependent Var: 0-0_S1 (eV)
# Intercept: -23.542711936512354, Linear Coeff: -19.45559983916421, Quadratic Coeff: -4.998251667982506, Cubic Coeff: -0.4300327322841646
# Independent Var: lumo-homo (eV), Dependent Var: 0-0_S1 (eV)
# Intercept: -0.20061494111547606, Linear Coeff: 0.05005912042472707, Quadratic Coeff: 0.3898586816147274, Cubic Coeff: -0.06227890316400237
# Independent Var: oxidation_S0 (kcal/mol), Dependent Var: 0-0_S1 (eV)
# Intercept: 0.253437291950354, Linear Coeff: 2.3060131152382175e-07, Quadratic Coeff: 6.901409004543718e-05, Cubic Coeff: -6.767124321759173e-11
# Independent Var: reduction_S0 (kcal/mol), Dependent Var: 0-0_S1 (eV)
# Intercept: -26.06289054052314, Linear Coeff: -0.8056869871194742, Quadratic Coeff: -0.0077950666868174204, Cubic Coeff: -2.5259153136891754e-05
# Independent Var: vertical_excitation_energy (eV), Dependent Var: 0-0_S1 (eV)
# Intercept: 0.2885145824844213, Linear Coeff: 0.16833715964831691, Quadratic Coeff: 0.29617573848788353, Cubic Coeff: -0.03366697685919648
# Independent Var: 0-0_S1 (eV), Dependent Var: 0-0_T1 (eV)
# Intercept: -1.1489657958228225, Linear Coeff: 2.5872813159805506, Quadratic Coeff: -1.074540918953078, Cubic Coeff: 0.20681367387551441
# Independent Var: adiabatic_S1-S0 (kcal/mol), Dependent Var: 0-0_T1 (eV)
# Intercept: -0.915897590284509, Linear Coeff: 0.0883750275408643, Quadratic Coeff: -0.0013175197007923077, Cubic Coeff: 1.0427747751590166e-05
# Independent Var: adiabatic_T1-S0 (kcal/mol), Dependent Var: 0-0_T1 (eV)
# Intercept: 0.03318632871267879, Linear Coeff: 0.04007426033349258, Quadratic Coeff: 0.00014451980940510475, Cubic Coeff: -1.6895933682078978e-06
# Independent Var: dipole_moment_norm_S0 (D), Dependent Var: 0-0_T1 (eV)
# Intercept: 1.2014190570592396, Linear Coeff: 0.05589294257246119, Quadratic Coeff: -0.007837950038345934, Cubic Coeff: 0.00017152376177419215
# Independent Var: dipole_moment_norm_S1 (D), Dependent Var: 0-0_T1 (eV)
# Intercept: 1.2296937792707368, Linear Coeff: 0.05580245146838484, Quadratic Coeff: -0.008235640624864248, Cubic Coeff: 0.00018715729557403082
# Independent Var: dipole_moment_norm_T1 (D), Dependent Var: 0-0_T1 (eV)
# Intercept: 1.3799127265996014, Linear Coeff: 0.02076728854688632, Quadratic Coeff: -0.0031642184563782875, Cubic Coeff: 5.831399985132407e-05
# Independent Var: homo (eV), Dependent Var: 0-0_T1 (eV)
# Intercept: 2.633193352643567, Linear Coeff: 2.0340930941724973, Quadratic Coeff: 0.4226658492694308, Cubic Coeff: 0.022905402750908577
# Independent Var: lumo (eV), Dependent Var: 0-0_T1 (eV)
# Intercept: -18.695571397635316, Linear Coeff: -14.464000685268699, Quadratic Coeff: -3.5522750820791478, Cubic Coeff: -0.2955640995841389
# Independent Var: lumo-homo (eV), Dependent Var: 0-0_T1 (eV)
# Intercept: -1.9706403262586234, Linear Coeff: 1.7445049381043705, Quadratic Coeff: -0.3263512266791332, Cubic Coeff: 0.031191043981064315
# Independent Var: oxidation_S0 (kcal/mol), Dependent Var: 0-0_T1 (eV)
# Intercept: -0.43306961527659715, Linear Coeff: 2.5261287210369306e-07, Quadratic Coeff: 7.440140790133873e-05, Cubic Coeff: -7.295373712935525e-11
# Independent Var: reduction_S0 (kcal/mol), Dependent Var: 0-0_T1 (eV)
# Intercept: -24.29182354500439, Linear Coeff: -0.6985356236045701, Quadratic Coeff: -0.0064571248956348005, Cubic Coeff: -2.019872370428999e-05
# Independent Var: vertical_excitation_energy (eV), Dependent Var: 0-0_T1 (eV)
# Intercept: -1.810844180916231, Linear Coeff: 2.8657608803437347, Quadratic Coeff: -1.1216666846738514, Cubic Coeff: 0.1973949846999825
# Independent Var: 0-0_S1 (eV), Dependent Var: adiabatic_T1-S0 (kcal/mol)
# Intercept: -25.560186529219887, Linear Coeff: 57.986385698936644, Quadratic Coeff: -23.904803820211484, Cubic Coeff: 4.577732141860416
# Independent Var: 0-0_T1 (eV), Dependent Var: adiabatic_T1-S0 (kcal/mol)
# Intercept: -0.4691849798655596, Linear Coeff: 24.37888967912449, Quadratic Coeff: -1.568682578527973, Cubic Coeff: 0.4341533064399279
# Independent Var: adiabatic_S1-S0 (kcal/mol), Dependent Var: adiabatic_T1-S0 (kcal/mol)
# Intercept: -22.675622555600604, Linear Coeff: 2.150387409166515, Quadratic Coeff: -0.03334058192446918, Cubic Coeff: 0.00026294312623287297
# Independent Var: dipole_moment_norm_S0 (D), Dependent Var: adiabatic_T1-S0 (kcal/mol)
# Intercept: 27.276849196399567, Linear Coeff: 1.3036062458411686, Quadratic Coeff: -0.18308044825245098, Cubic Coeff: 0.004062817963882415
# Independent Var: dipole_moment_norm_S1 (D), Dependent Var: adiabatic_T1-S0 (kcal/mol)
# Intercept: 27.941044185454587, Linear Coeff: 1.2949952325222118, Quadratic Coeff: -0.19164984756758963, Cubic Coeff: 0.004419491216075544
# Independent Var: dipole_moment_norm_T1 (D), Dependent Var: adiabatic_T1-S0 (kcal/mol)
# Intercept: 31.301965569045635, Linear Coeff: 0.5025920428754767, Quadratic Coeff: -0.07443577507315917, Cubic Coeff: 0.0013753437761962473
# Independent Var: homo (eV), Dependent Var: adiabatic_T1-S0 (kcal/mol)
# Intercept: 28.789090450440778, Linear Coeff: 32.43421814588453, Quadratic Coeff: 7.584574980775413, Cubic Coeff: 0.4228148309582238
# Independent Var: lumo (eV), Dependent Var: adiabatic_T1-S0 (kcal/mol)
# Intercept: -434.28541433790986, Linear Coeff: -335.4229077641323, Quadratic Coeff: -82.3315319694417, Cubic Coeff: -6.845328996518049
# Independent Var: lumo-homo (eV), Dependent Var: adiabatic_T1-S0 (kcal/mol)
# Intercept: -50.967740268208175, Linear Coeff: 46.23657477381305, Quadratic Coeff: -9.663201441979234, Cubic Coeff: 0.9550393816640508
# Independent Var: oxidation_S0 (kcal/mol), Dependent Var: adiabatic_T1-S0 (kcal/mol)
# Intercept: -9.859279621834876, Linear Coeff: 5.745130406950946e-06, Quadratic Coeff: 0.001692098218488576, Cubic Coeff: -1.659174096127067e-09
# Independent Var: reduction_S0 (kcal/mol), Dependent Var: adiabatic_T1-S0 (kcal/mol)
# Intercept: -500.79424037295956, Linear Coeff: -14.366450856084352, Quadratic Coeff: -0.13198834136465976, Cubic Coeff: -0.000411052498515474
# Independent Var: vertical_excitation_energy (eV), Dependent Var: adiabatic_T1-S0 (kcal/mol)
# Intercept: -43.39280020103093, Linear Coeff: 68.63223737126097, Quadratic Coeff: -27.21792964854056, Cubic Coeff: 4.757445298092151
# Independent Var: 0-0_S1 (eV), Dependent Var: adiabatic_S1-S0 (kcal/mol)
# Intercept: 0.3592033783481128, Linear Coeff: 23.468933571367756, Quadratic Coeff: -0.26582904946019603, Cubic Coeff: 0.01812748011127141
# Independent Var: 0-0_T1 (eV), Dependent Var: adiabatic_S1-S0 (kcal/mol)
# Intercept: 11.64344260483685, Linear Coeff: 26.760959673190627, Quadratic Coeff: 2.1524192653923215, Cubic Coeff: -2.651203354456758
# Independent Var: adiabatic_T1-S0 (kcal/mol), Dependent Var: adiabatic_S1-S0 (kcal/mol)
# Intercept: 11.87801922793091, Linear Coeff: 1.1455623329870486, Quadratic Coeff: 0.005305487277211921, Cubic Coeff: -0.0002373702910742903
# Independent Var: dipole_moment_norm_S0 (D), Dependent Var: adiabatic_S1-S0 (kcal/mol)
# Intercept: 41.944345214541556, Linear Coeff: 1.1172974146584533, Quadratic Coeff: -0.16487233933615836, Cubic Coeff: 0.0033539325845217682
# Independent Var: dipole_moment_norm_S1 (D), Dependent Var: adiabatic_S1-S0 (kcal/mol)
# Intercept: 42.71012197662173, Linear Coeff: 0.7992488661468009, Quadratic Coeff: -0.1283775256168741, Cubic Coeff: 0.0021920588319456202
# Independent Var: dipole_moment_norm_T1 (D), Dependent Var: adiabatic_S1-S0 (kcal/mol)
# Intercept: 43.84395480380122, Linear Coeff: 1.014520739530523, Quadratic Coeff: -0.11098461361300042, Cubic Coeff: 0.0019627713108039124
# Independent Var: homo (eV), Dependent Var: adiabatic_S1-S0 (kcal/mol)
# Intercept: 90.9557719467561, Linear Coeff: 59.111236756439624, Quadratic Coeff: 12.328946911435082, Cubic Coeff: 0.6962077226115255
# Independent Var: lumo (eV), Dependent Var: adiabatic_S1-S0 (kcal/mol)
# Intercept: -639.9448536104366, Linear Coeff: -514.3884012302892, Quadratic Coeff: -129.97696594116377, Cubic Coeff: -10.99868454529593
# Independent Var: lumo-homo (eV), Dependent Var: adiabatic_S1-S0 (kcal/mol)
# Intercept: -5.043325039109071, Linear Coeff: 4.210281814811111, Quadratic Coeff: 7.267413492027375, Cubic Coeff: -1.1884338130203105
# Independent Var: oxidation_S0 (kcal/mol), Dependent Var: adiabatic_S1-S0 (kcal/mol)
# Intercept: 5.835344341387916, Linear Coeff: 5.383072843225255e-06, Quadratic Coeff: 0.001596273477451732, Cubic Coeff: -1.5652138667375073e-09
# Independent Var: reduction_S0 (kcal/mol), Dependent Var: adiabatic_S1-S0 (kcal/mol)
# Intercept: -765.4112723368173, Linear Coeff: -22.970367292366486, Quadratic Coeff: -0.21878270470114447, Cubic Coeff: -0.0006976189891858553
# Independent Var: vertical_excitation_energy (eV), Dependent Var: adiabatic_S1-S0 (kcal/mol)
# Intercept: -0.36751774887121513, Linear Coeff: 16.940050753534305, Quadratic Coeff: -0.23809565023508483, Cubic Coeff: 0.4099476523436465
# Independent Var: 0-0_S1 (eV), Dependent Var: reduction_S0 (kcal/mol)
# Intercept: -79.33516911550765, Linear Coeff: -41.96874520681202, Quadratic Coeff: 25.256730727418653, Cubic Coeff: -5.032634369109395
# Independent Var: 0-0_T1 (eV), Dependent Var: reduction_S0 (kcal/mol)
# Intercept: -94.3494541589922, Linear Coeff: -12.229814991308638, Quadratic Coeff: 5.485671112324028, Cubic Coeff: -0.8932637503064615
# Independent Var: adiabatic_S1-S0 (kcal/mol), Dependent Var: reduction_S0 (kcal/mol)
# Intercept: -75.80603994393837, Linear Coeff: -1.9693098168272867, Quadratic Coeff: 0.04897257073264659, Cubic Coeff: -0.0004070176358850208
# Independent Var: adiabatic_T1-S0 (kcal/mol), Dependent Var: reduction_S0 (kcal/mol)
# Intercept: -94.55283283274058, Linear Coeff: -0.5278670893547416, Quadratic Coeff: 0.010678834931412065, Cubic Coeff: -8.069038161795383e-05
# Independent Var: dipole_moment_norm_S0 (D), Dependent Var: reduction_S0 (kcal/mol)
# Intercept: -103.56709147206162, Linear Coeff: 0.26276651138854984, Quadratic Coeff: -0.02485399062509252, Cubic Coeff: 0.0012284225664362936
# Independent Var: dipole_moment_norm_S1 (D), Dependent Var: reduction_S0 (kcal/mol)
# Intercept: -103.49179525808015, Linear Coeff: 0.3130897464435472, Quadratic Coeff: -0.03196225970437344, Cubic Coeff: 0.001411213129499822
# Independent Var: dipole_moment_norm_T1 (D), Dependent Var: reduction_S0 (kcal/mol)
# Intercept: -106.14955415482586, Linear Coeff: 0.6439224710130015, Quadratic Coeff: -0.02944697671591849, Cubic Coeff: 0.00043907025714251535
# Independent Var: homo (eV), Dependent Var: reduction_S0 (kcal/mol)
# Intercept: 241.3840257243328, Linear Coeff: 144.32735973963383, Quadratic Coeff: 20.797001505491703, Cubic Coeff: 1.0269934921015818
# Independent Var: lumo (eV), Dependent Var: reduction_S0 (kcal/mol)
# Intercept: -3.129384142468254, Linear Coeff: 35.78508964646495, Quadratic Coeff: 4.518059213892301, Cubic Coeff: 0.4811784792790732
# Independent Var: lumo-homo (eV), Dependent Var: reduction_S0 (kcal/mol)
# Intercept: -90.51726383868446, Linear Coeff: -4.486298441334367, Quadratic Coeff: -0.0017367053791335074, Cubic Coeff: 0.06139327129044769
# Independent Var: oxidation_S0 (kcal/mol), Dependent Var: reduction_S0 (kcal/mol)
# Intercept: -84.69435563873179, Linear Coeff: -2.706173268762183e-06, Quadratic Coeff: -0.0007986964819083242, Cubic Coeff: 7.831557850678757e-10
# Independent Var: vertical_excitation_energy (eV), Dependent Var: reduction_S0 (kcal/mol)
# Intercept: -85.25518974953859, Linear Coeff: -17.93025054296005, Quadratic Coeff: 6.632353727675024, Cubic Coeff: -0.9284844497467031
# Independent Var: 0-0_S1 (eV), Dependent Var: oxidation_S0 (kcal/mol)
# Intercept: 12812.467392791783, Linear Coeff: -28559.86698730838, Quadratic Coeff: 19836.952855959513, Cubic Coeff: -4223.891443427692
# Independent Var: 0-0_T1 (eV), Dependent Var: oxidation_S0 (kcal/mol)
# Intercept: -1086.8650540409274, Linear Coeff: 3181.046560127392, Quadratic Coeff: -1762.2368962013513, Cubic Coeff: 225.85985310797741
# Independent Var: adiabatic_S1-S0 (kcal/mol), Dependent Var: oxidation_S0 (kcal/mol)
# Intercept: 7806.115796866091, Linear Coeff: -748.9731907459532, Quadratic Coeff: 22.546163703969448, Cubic Coeff: -0.2079782474664853
# Independent Var: adiabatic_T1-S0 (kcal/mol), Dependent Var: oxidation_S0 (kcal/mol)
# Intercept: -1277.8480590012775, Linear Coeff: 179.87861898806557, Quadratic Coeff: -5.239892196721071, Cubic Coeff: 0.04195600443432568
# Independent Var: dipole_moment_norm_S0 (D), Dependent Var: oxidation_S0 (kcal/mol)
# Intercept: -600.9219886582754, Linear Coeff: 404.06577449262664, Quadratic Coeff: -40.312814649439574, Cubic Coeff: 1.0693394862227592
# Independent Var: dipole_moment_norm_S1 (D), Dependent Var: oxidation_S0 (kcal/mol)
# Intercept: -607.4304412951712, Linear Coeff: 428.97589722317105, Quadratic Coeff: -43.43374581841395, Cubic Coeff: 1.1597629456067011
# Independent Var: dipole_moment_norm_T1 (D), Dependent Var: oxidation_S0 (kcal/mol)
# Intercept: 2069.566133420947, Linear Coeff: -261.85060568218785, Quadratic Coeff: 10.70078696098824, Cubic Coeff: -0.1337743608824553
# Independent Var: homo (eV), Dependent Var: oxidation_S0 (kcal/mol)
# Intercept: 87898.63969414996, Linear Coeff: 40564.49801831584, Quadratic Coeff: 6155.212982134568, Cubic Coeff: 306.16568763573014
# Independent Var: lumo (eV), Dependent Var: oxidation_S0 (kcal/mol)
# Intercept: -26449.126960263235, Linear Coeff: -13714.484499389479, Quadratic Coeff: -1736.2378815888214, Cubic Coeff: 1.3229952212150238
# Independent Var: lumo-homo (eV), Dependent Var: oxidation_S0 (kcal/mol)
# Intercept: 14867.042828456202, Linear Coeff: -16788.344784148212, Quadratic Coeff: 6073.876456459543, Cubic Coeff: -693.7906643782462
# Independent Var: reduction_S0 (kcal/mol), Dependent Var: oxidation_S0 (kcal/mol)
# Intercept: 66294.78974773374, Linear Coeff: 2241.4101099841196, Quadratic Coeff: 24.662298524321958, Cubic Coeff: 0.08834237011569712
# Independent Var: vertical_excitation_energy (eV), Dependent Var: oxidation_S0 (kcal/mol)
# Intercept: 12317.422725818078, Linear Coeff: -20260.856732666794, Quadratic Coeff: 10561.492830785082, Cubic Coeff: -1725.8834714610894
# Independent Var: 0-0_S1 (eV), Dependent Var: lumo-homo (eV)
# Intercept: -0.24937426313801403, Linear Coeff: 3.642396739140391, Quadratic Coeff: -1.5113996941845993, Cubic Coeff: 0.294291259862963
# Independent Var: 0-0_T1 (eV), Dependent Var: lumo-homo (eV)
# Intercept: 1.5583643225974195, Linear Coeff: 0.9396317666320562, Quadratic Coeff: 0.506492119404993, Cubic Coeff: -0.18229663974534926
# Independent Var: adiabatic_S1-S0 (kcal/mol), Dependent Var: lumo-homo (eV)
# Intercept: -0.13815775656571905, Linear Coeff: 0.1423441397435516, Quadratic Coeff: -0.0023502914087501618, Cubic Coeff: 1.9573295389319068e-05
# Independent Var: adiabatic_T1-S0 (kcal/mol), Dependent Var: lumo-homo (eV)
# Intercept: 1.5789292537774733, Linear Coeff: 0.03965279754648288, Quadratic Coeff: 0.0010241682696888626, Cubic Coeff: -1.5918969476710898e-05
# Independent Var: dipole_moment_norm_S0 (D), Dependent Var: lumo-homo (eV)
# Intercept: 3.167391434972888, Linear Coeff: 0.06856673543991204, Quadratic Coeff: -0.011092121433366593, Cubic Coeff: 0.00024398762350431868
# Independent Var: dipole_moment_norm_S1 (D), Dependent Var: lumo-homo (eV)
# Intercept: 3.23801886459013, Linear Coeff: 0.05711465365302962, Quadratic Coeff: -0.010498781839530938, Cubic Coeff: 0.00023723457305739604
# Independent Var: dipole_moment_norm_T1 (D), Dependent Var: lumo-homo (eV)
# Intercept: 3.5623224550854573, Linear Coeff: 0.006298237208310712, Quadratic Coeff: -0.004142528835291226, Cubic Coeff: 8.143834617595994e-05
# Independent Var: homo (eV), Dependent Var: lumo-homo (eV)
# Intercept: 10.552176934776282, Linear Coeff: 4.99727169397709, Quadratic Coeff: 0.855727548596797, Cubic Coeff: 0.0419406985866253
# Independent Var: lumo (eV), Dependent Var: lumo-homo (eV)
# Intercept: -41.91808408863812, Linear Coeff: -34.00593098004834, Quadratic Coeff: -8.644492555059518, Cubic Coeff: -0.7396743821645941
# Independent Var: oxidation_S0 (kcal/mol), Dependent Var: lumo-homo (eV)
# Intercept: 0.6174426720577513, Linear Coeff: 3.7971291671131645e-07, Quadratic Coeff: 0.00011203368451505123, Cubic Coeff: -1.098537806202323e-10
# Independent Var: reduction_S0 (kcal/mol), Dependent Var: lumo-homo (eV)
# Intercept: -54.00070678458826, Linear Coeff: -1.6274345900431575, Quadratic Coeff: -0.01560875019534584, Cubic Coeff: -5.0406838536964926e-05
# Independent Var: vertical_excitation_energy (eV), Dependent Var: lumo-homo (eV)
# Intercept: -0.6913847717854109, Linear Coeff: 3.2295305487264923, Quadratic Coeff: -1.197291322723771, Cubic Coeff: 0.22590658515445572

# %%
# 첫 번째 모델에 대해 CSV 파일과 그래프 저장
for index, row in high_r2_models.iterrows():
    independent_var = row['Independent_Var']
    dependent_var = row['Dependent_Var']
    r2 = row['R2']
    
    # 결측치 제거
    valid_data = df[[independent_var, dependent_var]].dropna()
    
    X = valid_data[[independent_var]]
    y = valid_data[dependent_var]
    
    # 다항식 특징 변환기 생성 (차수 3으로 설정)
    poly = PolynomialFeatures(degree=3)
    X_poly = poly.fit_transform(X)
    
    # 모델 학습 및 예측
    model = LinearRegression()
    model.fit(X_poly, y)
    y_pred = model.predict(X_poly)
    
    # 실제 값과 예측치 저장
    result_df = pd.DataFrame({
        'Real': y,
        'Predict': y_pred
    })
    
    # 파일 이름에서 유효하지 않은 문자 제거
    def sanitize_filename(filename):
        return re.sub(r'[\\/*?:"<>|]', "_", filename)

    csv_filename = sanitize_filename(f'{independent_var}__{dependent_var}.csv')
    result_df.to_csv(csv_filename, index=False)
    
    # 그래프 생성
    plt.figure()
    plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k-', lw=2)
    plt.scatter(y, y_pred, color='red', alpha=0.5)
    plt.xlabel(f'Actual values of {dependent_var}')
    plt.ylabel(f'Predicted values of {dependent_var}')
    plt.title(f'Model: {independent_var}__{dependent_var}')

    # R^2 값 그래프에 추가
    plt.text(x=0.05, y=0.95, s=f'$R^2 = {r2:.4f}$', fontsize=12, ha='left', va='top', transform=plt.gca().transAxes)

    # 그래프 이미지 파일로 저장
    img_filename = sanitize_filename(f'{independent_var}__{dependent_var}.png')
    plt.savefig(img_filename)
    plt.close()
